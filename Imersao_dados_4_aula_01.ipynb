# %% [markdown]
# <a href="https://colab.research.google.com/github/alxfernandes/imersao_dados_4_alura/blob/main/Imersao_dados_4_aula_01.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Desafios

# %%
import pandas as pd
url = 'https://gist.githubusercontent.com/tgcsantos/3bdb29eba6ce391e90df2b72205ba891/raw/22fa920e80c9fa209a9fccc8b52d74cc95d1599b/dados_imoveis.csv'
dados = pd.read_csv(url)

# %% [markdown]
# #01 - Media da Metragem por bairro

# %%
bairros_media = dados.groupby('Bairro')['Metragem'].mean()
bairros_media
# Out:
# Bairro
# Aclimação            253.056818
# Alto da Boa Vista    418.875000
# Alto da Lapa         294.337209
# Alto da Mooca        270.050000
# Alto de Pinheiros    433.444988
#                         ...
# Vila Água Funda      152.200000
# Água Branca          191.000000
# Água Fria            165.416667
# Água Funda           139.000000
# Água Rasa            340.250000
# Name: Metragem, Length: 701, dtype: float64

# %% [markdown]
# #02 - Duas formas de selecionar os dados por bairro (consultar os métodos na documentação do pandas) (Thiago)

# %%
#Forma 1
dados.query('Bairro == "Alto de Pinheiros"')
# Out:
#                            Rua             Bairro     Cidade  Metragem  \
# 83       Rua Carlos Rath, 103   Alto de Pinheiros  São Paulo       400
# 84                         NaN  Alto de Pinheiros  São Paulo       358
# 137         Rua Aquiramun, 94   Alto de Pinheiros  São Paulo       450
# 214             Rua Açaré, 63   Alto de Pinheiros  São Paulo       252
# 226                Rua Banibás  Alto de Pinheiros  São Paulo       297
# ...                        ...                ...        ...       ...
# 9691                       NaN  Alto de Pinheiros  São Paulo       466
# 9696   Rua Sebastião Rodrigues  Alto de Pinheiros  São Paulo       150
# 9727                       NaN  Alto de Pinheiros  São Paulo       466
# 9732   Rua Sebastião Rodrigues  Alto de Pinheiros  São Paulo       150
# 9893  Rua Cardeal Cagliori, 1   Alto de Pinheiros  São Paulo       400
#
#       Quartos  Banheiros  Vagas                                  Valor
# ...

# %%
#Forma 2
dados[dados['Bairro'] == 'Alto de Pinheiros']
# Out:
#                            Rua             Bairro     Cidade  Metragem  \
# 83       Rua Carlos Rath, 103   Alto de Pinheiros  São Paulo       400
# 84                         NaN  Alto de Pinheiros  São Paulo       358
# 137         Rua Aquiramun, 94   Alto de Pinheiros  São Paulo       450
# 214             Rua Açaré, 63   Alto de Pinheiros  São Paulo       252
# 226                Rua Banibás  Alto de Pinheiros  São Paulo       297
# ...                        ...                ...        ...       ...
# 9691                       NaN  Alto de Pinheiros  São Paulo       466
# 9696   Rua Sebastião Rodrigues  Alto de Pinheiros  São Paulo       150
# 9727                       NaN  Alto de Pinheiros  São Paulo       466
# 9732   Rua Sebastião Rodrigues  Alto de Pinheiros  São Paulo       150
# 9893  Rua Cardeal Cagliori, 1   Alto de Pinheiros  São Paulo       400
#
#       Quartos  Banheiros  Vagas                                  Valor
# ...

# %% [markdown]
# # 03 - Explorar alguns gráficos na documentação e aplicar nas demais colunas do DF, tentar colocar alguma conclusão (Thiago)

# %%
dados['media_metragem_x_comodos'] = df_media_metragem_por_comodo = dados['Metragem'] / (dados['Quartos'] + dados['Banheiros'])
dados[dados['media_metragem_x_comodos'] < 500].plot.scatter(x='Quartos', y='media_metragem_x_comodos')
'''
Conclusão: foi necessário restringir a análise a m2 inferiores a 500m2 por comodo. Provavelmente existe uma distoção da 
metragem em relação ao número de comodos dos imóveis. Vemos que a medida que o número de comodos aumenta, seu tamanho diminui
insinuando que não necessariamente mais comodos indica um imóvel maior. 
'''

# %%
dados['Quartos'].hist()
#Conclusão: A maior parte da amostra são de imóveis entre 3 e 5 Quartos

# %%
dados[['Metragem']].plot.box()
#Conclusão: A coluna de Metragem possui um outlier considerável

# %%
dados['Bairro'].value_counts()[:25].plot.bar()
#Conclusão: Todos os 25 primeiros bairros possuem +100 imóveis à venda

# %% [markdown]
# #04 - Pegar outras estatísticas dos dados, média, mediana, mim, max (Vivi)

# %%
dados.describe()
# Out:
#             Metragem       Quartos     Banheiros         Vagas  \
# count   10008.000000  10008.000000  10008.000000  10008.000000
# mean      442.300659      3.483114      3.879097      4.097222
# std      7515.379389      1.064200      1.988467      2.824014
# min        10.000000      1.000000      1.000000      1.000000
# 25%       173.000000      3.000000      2.000000      2.000000
# 50%       290.000000      3.000000      4.000000      4.000000
# 75%       460.250000      4.000000      5.000000      5.000000
# max    750000.000000     16.000000     40.000000     50.000000
#
#        metragem_media_comodos
# count            10008.000000
# mean               117.980510
# std               1507.193282
# min                  3.333333
# 25%                 58.458333
# 50%                 85.000000
# 75%                125.000000
# max             150000.000000

# %%
dados[['Metragem','Quartos', 'Vagas','Banheiros']].median()
# Out:
# Metragem     290.0
# Quartos        3.0
# Vagas          4.0
# Banheiros      4.0
# dtype: float64

# %% [markdown]
# #5 - Descobrir quais são os bairros que não tem nome de Rua. (Vivi)

# %%
filtro = dados['Rua'].isnull()
dados[filtro]
# Out:
#       Rua                            Bairro     Cidade  Metragem  Quartos  \
# 3     NaN                    Jardim Morumbi  São Paulo       310        3
# 11    NaN                  Jardim Luzitânia  São Paulo       436        4
# 31    NaN                    Parque da Lapa  São Paulo       220        4
# 56    NaN  Chácara Santo Antônio (Zona Sul)  São Paulo       190        2
# 57    NaN                    Jardim Guedala  São Paulo       650        4
# ...   ...                               ...        ...       ...      ...
# 9963  NaN                 Jardim Petrópolis  São Paulo       423        5
# 9989  NaN              Parque Alves de Lima  São Paulo       127        2
# 9991  NaN                      Vila Formosa  São Paulo       145        3
# 9995  NaN                     Jardim Leonor  São Paulo      1350        5
# 9999  NaN                 Jardim Petrópolis  São Paulo       423        5
#
#       Banheiros  Vagas         Valor  metragem_media_comodos
# ...
